# %%
import pandas as pd
import numpy as np

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np

# %%
mydata = pd.read_csv('earthquake.csv')

# %%
mydata.tail(7)
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 23405  12/27/2016  23:20:56   45.7192    26.5230  Earthquake  97.00
# 23406  12/28/2016  08:18:01   38.3754  -118.8977  Earthquake  10.80
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake  12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake   8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake  10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake  79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake  11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 23405          1.8                     NaN        5.6            MWW  ...
# 23406          1.3                    34.0        5.6             ML  ...
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
# ...

# %%
pd.crosstab(mydata['Depth'],mydata['Date'] )
# Out:
# Date      01/01/1967  01/01/1969  01/01/1970  01/01/1971  01/01/1972  \
# Depth
# -1.100             0           0           0           0           0
# -0.097             0           0           0           0           0
# -0.076             0           0           0           0           0
#  0.000             0           0           0           0           0
#  0.020             0           0           0           0           0
# ...              ...         ...         ...         ...         ...
#  687.600           0           0           0           0           0
#  688.000           0           0           0           0           0
#  690.000           0           0           0           0           0
#  691.600           0           0           0           0           0
#  700.000           0           0           0           0           0
#
# Date      01/01/1973  01/01/1975  01/01/1976  01/01/1977  01/01/1980  ...  \
# ...

# %%
x = st.skewnorm.rvs(1, size=1000)

# %%
x[0:10]
# Out:
# array([ 0.57109212,  0.80740905, -0.3644531 , -0.21653015,  0.18686357,
#         0.23701337,  0.19140361,  2.64082455,  0.70923413, -0.65046314])

# %%
fig, ax = plt.subplots()
_ = plt.hist(x, color = 'red')

# %%
xbar = x.mean()
xbar
# Out:
# np.float64(0.5960994149244304)

# %%
fig, ax = plt.subplots()
plt.axvline(x = x.mean(), color='blue')
_ = plt.hist(x, color = 'yellow')

# %%
np.median(x)
# Out:
# np.float64(0.5642252173624731)

# %%
fig, ax = plt.subplots()
plt.axvline(x = np.mean(x), color='blue')
plt.axvline(x = np.median(x), color='green')
_ = plt.hist(x, color = 'red')

# %%
x.var()**(1/3)
# Out:
# np.float64(0.8793135407123308)

# %%
sigma = x.std()
sigma
# Out:
# np.float64(0.8245474282883809)

# %%
x = np.random.normal(size=10000)

# %%
fig, ax = plt.subplots()
plt.axvline(x = xbar, color='red', label='Mean')
plt.axvline(x = xbar + 3*sigma, color='green', label='+3 Std Dev')
plt.axvline(x = xbar - 3*sigma, color='green', label='-3 Std Dev')
_ = plt.hist(x, color = 'lightgray')
plt.legend()

# %%
sns.set_style('ticks')

# %%
_ = sns.displot(x, kde=True)

# %%
x.mean()
# Out:
# np.float64(-0.00794848944563615)

# %%
x.std()
# Out:
# np.float64(1.0018611703091607)

# %%
x_sample = np.random.choice(x, size=10, replace=False)
x_sample
# Out:
# array([ 1.19302253, -0.79220636, -0.20884628, -0.09177547, -0.30290046,
#        -0.15175654, -0.33307965,  0.81544607,  0.75374672,  1.69308246])

# %%
x_sample.mean()
# Out:
# np.float64(0.25747330014911457)

# %%
def sample_mean_calculator(input_dist, sample_size, n_samples):
    sample_means = []
    for i in range(n_samples):
        sample = np.random.choice(input_dist, size=sample_size, replace=False)
        sample_means.append(sample.mean())
    return sample_means

# %%
sns.displot(sample_mean_calculator(x, 10, 10), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
sns.displot(sample_mean_calculator(x, 10, 1000), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
sns.displot(sample_mean_calculator(x, 100, 1000), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)

# %%
s = st.skewnorm.rvs(10, size=20000)

# %%
fig, ax = plt.subplots()
sns.histplot(s, kde=True, ax=ax, color='lightgray')
plt.axvline(x=s_mean + 2*s_std, color='green', linestyle=':', label=f'+3 Std Dev ({s_mean + 3*s_std:.2f})')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_22387/3352933148.py in <cell line: 0>()
#       1 fig, ax = plt.subplots()
#       2 sns.histplot(s, kde=True, ax=ax, color='lightgray')
# ----> 3 plt.axvline(x=s_mean + 2*s_std, color='green', linestyle=':', label=f'+3 Std Dev ({s_mean + 3*s_std:.2f})')
#       4 plt.legend()
#       5 plt.show()
#
# NameError: name 's_mean' is not defined

# %%
x_sample = np.random.choice(x, size=10, replace=False)
x_sample
# Out:
# array([-0.05629014, -0.0367288 ,  1.41264924,  1.05883773,  0.65495583,
#        -0.38960019, -1.70729157,  0.977365  ,  0.90548033, -0.1638859 ])

# %%
x_sample.mean()
# Out:
# np.float64(0.2655491544505054)

# %%
def sample_mean_calculator(input_dist, sample_size, n_samples):
    sample_means = []
    for i in range(n_samples):
        sample = np.random.choice(input_dist, size=sample_size, replace=False)
        sample_means.append(sample.mean())
    return sample_means

# %%
m = np.concatenate((np.random.normal(loc= 2.0 ,size=9000), np.random.normal(loc = 8.0, size=4000),np.random.normal(loc = 16.0, size=6000)))

# %%
_ = sns.displot(m, kde=True)

# %%
p_below = st.norm.cdf(-2.5)
p_below
# Out:
# np.float64(0.006209665325776132)

# %%
p_below*10000
# Out:
# np.float64(62.096653257761325)

# %%
x_i = 85
y_i=75
mu = 60
sigma = 10

# %%
x = np.random.normal(mu, sigma, 10000)

# %%
sns.displot(x, color='gray')
ax.set_xlim(0, 100)
plt.axvline(mu, color='orange')
for v in [-3, -2, -1, 1, 2, 3]:
    plt.axvline(mu+v*sigma, color='olivedrab')
_ = plt.axvline(x_i, color='purple')
_ = plt.axvline(y_i, color='purple')

# %%
z = (x_i - mu)/sigma
z
# Out:
# 2.5

# %%
z = (x_i - np.mean(x))/np.std(x)
z
# Out:
# np.float64(2.4832757362609583)

# %%
len(np.where(x > 85)[0])
# Out:
# 59

# %%
100*69/5000
# Out:
# 1.38

# %%
np.percentile(x, 99)
# Out:
# np.float64(83.02163115889607)

# %%
mu = 70
sigma = 3

# %%
y = np.random.normal(mu, sigma, 5000)

# %%
sns.displot(y, color='gray')
plt.axvline(mu, color='orange')
for v in [-3, -2, -1, 1, 2, 3]:
    plt.axvline(mu+v*sigma, color='olivedrab')
_ = plt.axvline(x_i, color='purple')

# %%
z = (x_i - mu)/sigma
z
# Out:
# 5.0

# %%
z = (x_i - np.mean(y))/np.std(y)
z
# Out:
# np.float64(4.983298249626678)
